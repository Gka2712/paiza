# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.plot([0,1,2,3,4],[1,4,3,2,5])
plt.show()

# %%
plt.plot([1,4,3,2,5])
plt.show()

# %%
plt.bar(range(5),[1,4,3,2,5])
plt.show()

# %%
plt.barh(range(5),[1,4,3,2,5])
plt.show()
